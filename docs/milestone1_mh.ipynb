# %% [markdown]
# # NLP Milestone 1
# We get our data by running the bash script `./data/download_svn.sh`.

# %%
import subprocess
subprocess.call("../data/download_svn.sh")
# Out:
# A    data_brise
# A    data_brise/test
# A    data_brise/test/7327.json
# A    data_brise/test/7356.json
# A    data_brise/test/7447.json
# A    data_brise/test/7460e.json
# A    data_brise/test/7531e.json
# A    data_brise/test/7543e.json
# A    data_brise/test/7700.json
# A    data_brise/test/7746.json
# A    data_brise/test/7805.json
# A    data_brise/test/7913.json
# A    data_brise/test/7916.json
# A    data_brise/test/7947.json
# A    data_brise/test/7951.json
# A    data_brise/test/7962.json
# A    data_brise/test/7988.json
# A    data_brise/test/8049.json
# A    data_brise/test/8159.json
# A    data_brise/test/8165.json
# A    data_brise/test/8193.json
# A    data_brise/test/8208.json
# A    data_brise/test/8215.json
# A    data_brise/test/8229.json
# A    data_brise/test/8255.json
# A    data_brise/test/8260.json
# A    data_brise/test/8315.json
# A    data_brise/train
# A    data_brise/train/6770.json
# A    data_brise/train/6796e2.json
# A    data_brise/train/6817e.json
# ...
